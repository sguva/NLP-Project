# %%
import pandas as pd
import numpy as np
import nltk
from nltk import pos_tag, word_tokenize
import re
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import precision_score, recall_score, f1_score

# %%
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to /home/efk7cz/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/efk7cz/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %% [markdown]
# To run it on results from our experiments set the variable 'use_saved_results' to True

# %%
use_saved_results = True
if use_saved_results:
    df = pd.read_csv('saved_files_from_our_experiments/answer_generation_results.csv')

else:
    df = pd.read_csv('answer_generation_results.csv')

df
# Out:
#       row_id  image_id                                           question  \
# 0          0    289343             Where is the dog located in the image?
# 1          1    289343          Where is the person located in the image?
# 2          2    289343  Where is the dog located in the image and wher...
# 3          3    289343  Where are the dog and the person located in th...
# 4          4    289343      What is the position of the dog in the image?
# ...      ...       ...                                                ...
# 4995    4995    226984  Provide information about the location of the ...
# 4996    4996    226984  Elaborate on the whereabouts of the sink in th...
# 4997    4997    226984  Provide information about the location of the ...
# 4998    4998    226984  Provide information about the location of the ...
# 4999    4999    226984  Identify the general area where the oven is lo...
#
#                                                  answer  \
# 0     The dog is located at the middleRight of the i...
# 1     The person is located at the middleCenter of t...
# 2     The dog is located at the middleRight and the ...
# 3     The dog is located at the middleRight and the ...
# 4     The dog is located at the middleRight of the i...
# ...                                                 ...
# 4995  The oven is located at the middleCenter of the...
# 4996  The sink is located at the middleLeft of the i...
# 4997  The oven is located at the middleCenter and th...
# 4998  The oven is located at the middleCenter and th...
# 4999  The oven is located at the middleCenter of the...
#
#                                        generated_answer
# 0     The dog is located at the middleLeft of the im...
# 1     The person is located at the middleCenter of t...
# 2     The dog is located at the middleLeft and the p...
# 3     The dog is located at the middleLeft and the p...
# 4     The dog is located at the middleLeft of the im...
# ...                                                 ...
# 4995  The oven is located at the middleCenter of the...
# 4996  The sink is located at the middleCenter of the...
# 4997  The oven is located at the middleCenter and th...
# 4998  The oven is located at the middleCenter and th...
# 4999  The oven is located at the middleCenter of the...
#
# [5000 rows x 5 columns]

# %%
data_list = []
for _, row in df.iterrows():
    answer = row['answer']
    generated_answer = row['generated_answer']
    data_list.append((answer, generated_answer))

# %%
list_size = len(data_list)
print(f"The size of the list is: {list_size}")
# Out:
# The size of the list is: 5000

# %% [markdown]
# Fetch the category and object from the answer

# %%
def extract_object(sentence):
    tokens = word_tokenize(sentence)
    tagged_tokens = pos_tag(tokens)

    for token, pos in tagged_tokens:
        if pos in ['NN', 'NNS']:
            return token
    return None

def extract_positions(sentence):

    pattern = r'\b(topLeft|topCenter|topRight|middleRight|middleCenter|middleLeft|bottomLeft|bottomCenter|middleRight)\b'

    # Search for the pattern in the sentence
    match = re.search(pattern, sentence)

    # If a match is found, return the matched position
    if match:
        return match.group(1)
    else:
        return None

# %%
def getObjectAndPosition(sentences):
  result_dict = {}
  statements = sentences.split("and")
  for statement in statements:
    extracted_object = extract_object(statement)
    extracted_position = extract_positions(statement)
    result_dict[extracted_object] = extracted_position
  return result_dict

def evaluatedScore(index,original_dict, generated_dict):
  total_score = 0

  # Iterate through the keys of dict1
  for key in original_dict:
    if key in generated_dict:

      #Calculating total score for accuracy
      if original_dict[key] == generated_dict[key]:
        total_score+=1
      else:
        print(f"Index: {index} , Values for key '{key}' are not equal.")
    else:
      print(f"Key '{key}' is not present in Genrated Dictionary , Index: {index}.")
  return total_score

# %%
original_values_array = np.array([])
generated_values_array = np.array([])
pos_score = 0
total_sentences = 0
for index, data_info in enumerate(data_list):
    orig_answer, gen_answer = data_info
    orig_objPos = getObjectAndPosition(orig_answer)
    gen_objPos = getObjectAndPosition(gen_answer)
    total_sentences += len(orig_objPos)
    pos_score += evaluatedScore(index,orig_objPos,gen_objPos)
print(f'Positve Score {pos_score} , totalSentences:- {total_sentences}, Accuracy = {pos_score*100/total_sentences}')
# Out:
# Index: 0 , Values for key 'dog' are not equal.
# Index: 2 , Values for key 'dog' are not equal.
# Index: 3 , Values for key 'dog' are not equal.
# Index: 4 , Values for key 'dog' are not equal.
# Index: 6 , Values for key 'dog' are not equal.
# Index: 7 , Values for key 'dog' are not equal.
# Index: 8 , Values for key 'dog' are not equal.
# Index: 10 , Values for key 'dog' are not equal.
# Index: 11 , Values for key 'dog' are not equal.
# Index: 13 , Values for key 'bench' are not equal.
# Index: 15 , Values for key 'bench' are not equal.
# Index: 17 , Values for key 'bench' are not equal.
# Index: 18 , Values for key 'bench' are not equal.
# Index: 24 , Values for key 'bench' are not equal.
# Index: 26 , Values for key 'bench' are not equal.
# Index: 27 , Values for key 'bench' are not equal.
# Index: 28 , Values for key 'bench' are not equal.
# Index: 30 , Values for key 'bench' are not equal.
# Index: 31 , Values for key 'bench' are not equal.
# Index: 32 , Values for key 'bench' are not equal.
# Index: 34 , Values for key 'bench' are not equal.
# Index: 34 , Values for key 'bicycle' are not equal.
# Index: 35 , Values for key 'bicycle' are not equal.
# Index: 36 , Values for key 'dog' are not equal.
# Index: 38 , Values for key 'dog' are not equal.
# Index: 38 , Values for key 'bottle' are not equal.
# Index: 39 , Values for key 'dog' are not equal.
# Index: 39 , Values for key 'bottle' are not equal.
# Index: 40 , Values for key 'dog' are not equal.
# Index: 41 , Values for key 'bottle' are not equal.
# Index: 42 , Values for key 'dog' are not equal.
# Index: 42 , Values for key 'bottle' are not equal.
# Index: 43 , Values for key 'dog' are not equal.
# Index: 44 , Values for key 'dog' are not equal.
# Index: 46 , Values for key 'dog' are not equal.
# Index: 46 , Values for key 'bottle' are not equal.
# Index: 47 , Values for key 'dog' are not equal.
# Index: 47 , Values for key 'bottle' are not equal.
# Index: 48 , Values for key 'bottle' are not equal.
# Index: 49 , Values for key 'toilet' are not equal.
# Index: 50 , Values for key 'bottle' are not equal.
# Index: 50 , Values for key 'toilet' are not equal.
# Index: 51 , Values for key 'bottle' are not equal.
# Index: 51 , Values for key 'toilet' are not equal.
# Index: 52 , Values for key 'bottle' are not equal.
# Index: 53 , Values for key 'toilet' are not equal.
# Index: 54 , Values for key 'bottle' are not equal.
# Index: 54 , Values for key 'toilet' are not equal.
# Index: 55 , Values for key 'bottle' are not equal.
# Index: 55 , Values for key 'toilet' are not equal.
# Index: 56 , Values for key 'bottle' are not equal.
# Index: 57 , Values for key 'toilet' are not equal.
# Index: 58 , Values for key 'toilet' are not equal.
# Index: 59 , Values for key 'bottle' are not equal.
# Index: 59 , Values for key 'toilet' are not equal.
# Index: 60 , Values for key 'dog' are not equal.
# Index: 61 , Values for key 'motorcycle' are not equal.
# Index: 62 , Values for key 'dog' are not equal.
# Index: 62 , Values for key 'motorcycle' are not equal.
# Index: 63 , Values for key 'dog' are not equal.
# Index: 63 , Values for key 'motorcycle' are not equal.
# Index: 64 , Values for key 'dog' are not equal.
# Index: 65 , Values for key 'motorcycle' are not equal.
# Index: 66 , Values for key 'dog' are not equal.
# Index: 66 , Values for key 'motorcycle' are not equal.
# Index: 67 , Values for key 'dog' are not equal.
# Index: 67 , Values for key 'motorcycle' are not equal.
# Index: 68 , Values for key 'dog' are not equal.
# Index: 69 , Values for key 'motorcycle' are not equal.
# Index: 70 , Values for key 'dog' are not equal.
# Index: 70 , Values for key 'motorcycle' are not equal.
# Index: 71 , Values for key 'dog' are not equal.
# Index: 71 , Values for key 'motorcycle' are not equal.
# Index: 72 , Values for key 'dog' are not equal.
# Index: 74 , Values for key 'person' are not equal.
# Index: 75 , Values for key 'person' are not equal.
# Index: 76 , Values for key 'person' are not equal.
# Index: 78 , Values for key 'person' are not equal.
# Index: 79 , Values for key 'person' are not equal.
# Index: 80 , Values for key 'person' are not equal.
# Index: 82 , Values for key 'person' are not equal.
# Index: 83 , Values for key 'person' are not equal.
# Index: 84 , Values for key 'person' are not equal.
# Index: 85 , Values for key 'dog' are not equal.
# Index: 86 , Values for key 'spoon' are not equal.
# Index: 87 , Values for key 'dog' are not equal.
# Index: 87 , Values for key 'spoon' are not equal.
# Index: 88 , Values for key 'dog' are not equal.
# Index: 88 , Values for key 'spoon' are not equal.
# Index: 89 , Values for key 'dog' are not equal.
# Index: 90 , Values for key 'spoon' are not equal.
# Index: 91 , Values for key 'dog' are not equal.
# Index: 91 , Values for key 'spoon' are not equal.
# Index: 92 , Values for key 'dog' are not equal.
# Index: 93 , Values for key 'dog' are not equal.
# Index: 94 , Values for key 'spoon' are not equal.
# Index: 95 , Values for key 'dog' are not equal.
# Index: 96 , Values for key 'dog' are not equal.
# Index: 97 , Values for key 'spoon' are not equal.
# Index: 98 , Values for key 'bottle' are not equal.
# Index: 99 , Values for key 'spoon' are not equal.
# Index: 99 , Values for key 'bottle' are not equal.
# Index: 100 , Values for key 'spoon' are not equal.
# Index: 100 , Values for key 'bottle' are not equal.
# Index: 101 , Values for key 'spoon' are not equal.
# Index: 103 , Values for key 'spoon' are not equal.
# Index: 103 , Values for key 'bottle' are not equal.
# Index: 104 , Values for key 'spoon' are not equal.
# Index: 104 , Values for key 'bottle' are not equal.
# Index: 105 , Values for key 'spoon' are not equal.
# Index: 107 , Values for key 'spoon' are not equal.
# Index: 107 , Values for key 'bottle' are not equal.
# Index: 108 , Values for key 'spoon' are not equal.
# Index: 108 , Values for key 'bottle' are not equal.
# Index: 109 , Values for key 'dog' are not equal.
# Index: 110 , Values for key 'chair' are not equal.
# Index: 111 , Values for key 'dog' are not equal.
# Index: 111 , Values for key 'chair' are not equal.
# Index: 112 , Values for key 'dog' are not equal.
# Index: 112 , Values for key 'chair' are not equal.
# Index: 113 , Values for key 'dog' are not equal.
# Index: 114 , Values for key 'chair' are not equal.
# Index: 115 , Values for key 'dog' are not equal.
# Index: 116 , Values for key 'dog' are not equal.
# Index: 117 , Values for key 'dog' are not equal.
# Index: 118 , Values for key 'chair' are not equal.
# Index: 119 , Values for key 'dog' are not equal.
# Index: 120 , Values for key 'dog' are not equal.
# Index: 122 , Values for key 'plant' are not equal.
# Index: 123 , Values for key 'plant' are not equal.
# Index: 126 , Values for key 'plant' are not equal.
# Index: 127 , Values for key 'plant' are not equal.
# Index: 128 , Values for key 'plant' are not equal.
# Index: 130 , Values for key 'plant' are not equal.
# Index: 131 , Values for key 'plant' are not equal.
# Index: 132 , Values for key 'plant' are not equal.
# Index: 134 , Values for key 'chair' are not equal.
# Index: 135 , Values for key 'chair' are not equal.
# Index: 136 , Values for key 'chair' are not equal.
# Index: 138 , Values for key 'chair' are not equal.
# Index: 139 , Values for key 'chair' are not equal.
# Index: 140 , Values for key 'chair' are not equal.
# Index: 142 , Values for key 'chair' are not equal.
# Index: 143 , Values for key 'chair' are not equal.
# Index: 144 , Values for key 'chair' are not equal.
# Index: 145 , Values for key 'chair' are not equal.
# Index: 146 , Values for key 'bench' are not equal.
# Index: 147 , Values for key 'chair' are not equal.
# Index: 147 , Values for key 'bench' are not equal.
# Index: 148 , Values for key 'chair' are not equal.
# Index: 148 , Values for key 'bench' are not equal.
# Index: 149 , Values for key 'chair' are not equal.
# Index: 150 , Values for key 'bench' are not equal.
# Index: 151 , Values for key 'chair' are not equal.
# Index: 151 , Values for key 'bench' are not equal.
# Index: 152 , Values for key 'chair' are not equal.
# Index: 152 , Values for key 'bench' are not equal.
# Index: 153 , Values for key 'chair' are not equal.
# Index: 154 , Values for key 'bench' are not equal.
# Index: 155 , Values for key 'chair' are not equal.
# Index: 155 , Values for key 'bench' are not equal.
# Index: 156 , Values for key 'chair' are not equal.
# Index: 156 , Values for key 'bench' are not equal.
# Index: 157 , Values for key 'bench' are not equal.
# Index: 158 , Values for key 'wine' are not equal.
# Index: 159 , Values for key 'bench' are not equal.
# Index: 159 , Values for key 'wine' are not equal.
# Index: 160 , Values for key 'bench' are not equal.
# Index: 160 , Values for key 'wine' are not equal.
# Index: 161 , Values for key 'bench' are not equal.
# Index: 162 , Values for key 'wine' are not equal.
# Index: 163 , Values for key 'bench' are not equal.
# Index: 163 , Values for key 'wine' are not equal.
# Index: 164 , Values for key 'bench' are not equal.
# Index: 164 , Values for key 'wine' are not equal.
# Index: 165 , Values for key 'bench' are not equal.
# Index: 166 , Values for key 'wine' are not equal.
# Index: 167 , Values for key 'bench' are not equal.
# Index: 167 , Values for key 'wine' are not equal.
# Index: 168 , Values for key 'bench' are not equal.
# Index: 168 , Values for key 'wine' are not equal.
# Index: 169 , Values for key 'wine' are not equal.
# Index: 170 , Values for key 'cup' are not equal.
# Index: 171 , Values for key 'wine' are not equal.
# Index: 171 , Values for key 'cup' are not equal.
# Index: 172 , Values for key 'wine' are not equal.
# Index: 172 , Values for key 'cup' are not equal.
# Index: 173 , Values for key 'wine' are not equal.
# Index: 174 , Values for key 'cup' are not equal.
# Index: 175 , Values for key 'wine' are not equal.
# Index: 175 , Values for key 'cup' are not equal.
# Index: 176 , Values for key 'wine' are not equal.
# Index: 176 , Values for key 'cup' are not equal.
# Index: 177 , Values for key 'wine' are not equal.
# Index: 178 , Values for key 'cup' are not equal.
# Index: 179 , Values for key 'wine' are not equal.
# Index: 179 , Values for key 'cup' are not equal.
# Index: 180 , Values for key 'wine' are not equal.
# Index: 180 , Values for key 'cup' are not equal.
# Index: 181 , Values for key 'cup' are not equal.
# Index: 183 , Values for key 'cup' are not equal.
# Index: 183 , Values for key 'oven' are not equal.
# Index: 184 , Values for key 'cup' are not equal.
# Index: 184 , Values for key 'oven' are not equal.
# Index: 185 , Values for key 'cup' are not equal.
# Index: 187 , Values for key 'cup' are not equal.
# Index: 187 , Values for key 'oven' are not equal.
# Index: 188 , Values for key 'cup' are not equal.
# Index: 188 , Values for key 'oven' are not equal.
# Index: 189 , Values for key 'cup' are not equal.
# Index: 191 , Values for key 'cup' are not equal.
# Index: 191 , Values for key 'oven' are not equal.
# Index: 192 , Values for key 'cup' are not equal.
# Index: 192 , Values for key 'oven' are not equal.
# Index: 193 , Values for key 'dog' are not equal.
# Index: 194 , Values for key 'plant' are not equal.
# Index: 195 , Values for key 'dog' are not equal.
# Index: 195 , Values for key 'plant' are not equal.
# Index: 196 , Values for key 'dog' are not equal.
# Index: 196 , Values for key 'plant' are not equal.
# Index: 197 , Values for key 'dog' are not equal.
# Index: 198 , Values for key 'plant' are not equal.
# Index: 199 , Values for key 'dog' are not equal.
# Index: 199 , Values for key 'plant' are not equal.
# Index: 200 , Values for key 'dog' are not equal.
# Index: 200 , Values for key 'plant' are not equal.
# Index: 201 , Values for key 'dog' are not equal.
# Index: 202 , Values for key 'plant' are not equal.
# Index: 203 , Values for key 'dog' are not equal.
# Index: 203 , Values for key 'plant' are not equal.
# Index: 204 , Values for key 'plant' are not equal.
# Index: 205 , Values for key 'plant' are not equal.
# Index: 206 , Values for key 'tv' are not equal.
# Index: 207 , Values for key 'plant' are not equal.
# Index: 207 , Values for key 'tv' are not equal.
# Index: 208 , Values for key 'plant' are not equal.
# Index: 208 , Values for key 'tv' are not equal.
# Index: 209 , Values for key 'plant' are not equal.
# Index: 210 , Values for key 'tv' are not equal.
# Index: 211 , Values for key 'plant' are not equal.
# Index: 211 , Values for key 'tv' are not equal.
# Index: 212 , Values for key 'plant' are not equal.
# Index: 212 , Values for key 'tv' are not equal.
# Index: 213 , Values for key 'plant' are not equal.
# Index: 214 , Values for key 'tv' are not equal.
# Index: 215 , Values for key 'plant' are not equal.
# Index: 215 , Values for key 'tv' are not equal.
# Index: 216 , Values for key 'plant' are not equal.
# Index: 216 , Values for key 'tv' are not equal.
# Index: 217 , Values for key 'tv' are not equal.
# Index: 218 , Values for key 'person' are not equal.
# Index: 219 , Values for key 'tv' are not equal.
# Index: 219 , Values for key 'person' are not equal.
# Index: 220 , Values for key 'tv' are not equal.
# Index: 220 , Values for key 'person' are not equal.
# Index: 221 , Values for key 'tv' are not equal.
# Index: 222 , Values for key 'person' are not equal.
# Index: 223 , Values for key 'tv' are not equal.
# Index: 223 , Values for key 'person' are not equal.
# Index: 224 , Values for key 'tv' are not equal.
# Index: 224 , Values for key 'person' are not equal.
# Index: 225 , Values for key 'tv' are not equal.
# Index: 226 , Values for key 'person' are not equal.
# Index: 227 , Values for key 'tv' are not equal.
# Index: 227 , Values for key 'person' are not equal.
# Index: 228 , Values for key 'tv' are not equal.
# Index: 228 , Values for key 'person' are not equal.
# Index: 229 , Values for key 'person' are not equal.
# Index: 230 , Values for key 'bear' are not equal.
# Index: 231 , Values for key 'person' are not equal.
# Index: 232 , Values for key 'person' are not equal.
# Index: 233 , Values for key 'person' are not equal.
# Index: 234 , Values for key 'bear' are not equal.
# Index: 235 , Values for key 'person' are not equal.
# Index: 235 , Values for key 'bear' are not equal.
# Index: 236 , Values for key 'person' are not equal.
# Index: 236 , Values for key 'bear' are not equal.
# Index: 237 , Values for key 'person' are not equal.
# Index: 238 , Values for key 'bear' are not equal.
# Index: 239 , Values for key 'person' are not equal.
# Index: 239 , Values for key 'bear' are not equal.
# Index: 240 , Values for key 'person' are not equal.
# Index: 240 , Values for key 'bear' are not equal.
# Index: 242 , Values for key 'person' are not equal.
# Index: 246 , Values for key 'person' are not equal.
# Index: 250 , Values for key 'person' are not equal.
# Index: 253 , Values for key 'person' are not equal.
# Index: 254 , Values for key 'knife' are not equal.
# Index: 255 , Values for key 'person' are not equal.
# Index: 255 , Values for key 'knife' are not equal.
# Index: 256 , Values for key 'person' are not equal.
# Index: 256 , Values for key 'knife' are not equal.
# Index: 257 , Values for key 'person' are not equal.
# Index: 258 , Values for key 'knife' are not equal.
# Index: 259 , Values for key 'person' are not equal.
# Index: 259 , Values for key 'knife' are not equal.
# Index: 260 , Values for key 'person' are not equal.
# Index: 260 , Values for key 'knife' are not equal.
# Index: 261 , Values for key 'person' are not equal.
# Index: 262 , Values for key 'knife' are not equal.
# Index: 263 , Values for key 'person' are not equal.
# Index: 263 , Values for key 'knife' are not equal.
# Index: 264 , Values for key 'person' are not equal.
# Index: 264 , Values for key 'knife' are not equal.
# Index: 265 , Values for key 'knife' are not equal.
# Index: 267 , Values for key 'knife' are not equal.
# Index: 268 , Values for key 'knife' are not equal.
# Index: 269 , Values for key 'knife' are not equal.
# Index: 271 , Values for key 'knife' are not equal.
# Index: 272 , Values for key 'knife' are not equal.
# Index: 273 , Values for key 'knife' are not equal.
# Index: 275 , Values for key 'knife' are not equal.
# Index: 276 , Values for key 'knife' are not equal.
# Index: 278 , Values for key 'sink' are not equal.
# Index: 279 , Values for key 'sink' are not equal.
# Index: 280 , Values for key 'sink' are not equal.
# Index: 282 , Values for key 'sink' are not equal.
# Index: 283 , Values for key 'sink' are not equal.
# Index: 284 , Values for key 'sink' are not equal.
# Index: 286 , Values for key 'sink' are not equal.
# Index: 287 , Values for key 'sink' are not equal.
# Index: 288 , Values for key 'sink' are not equal.
# Index: 289 , Values for key 'dog' are not equal.
# Index: 291 , Values for key 'dog' are not equal.
# Index: 292 , Values for key 'dog' are not equal.
# Index: 293 , Values for key 'dog' are not equal.
# Index: 294 , Values for key 'bottle' are not equal.
# Index: 295 , Values for key 'dog' are not equal.
# Index: 296 , Values for key 'dog' are not equal.
# Index: 296 , Values for key 'bottle' are not equal.
# Index: 297 , Values for key 'dog' are not equal.
# Index: 298 , Values for key 'bottle' are not equal.
# Index: 299 , Values for key 'dog' are not equal.
# Index: 300 , Values for key 'dog' are not equal.
# Index: 301 , Values for key 'bottle' are not equal.
# Index: 302 , Values for key 'toilet' are not equal.
# Index: 304 , Values for key 'bottle' are not equal.
# Index: 304 , Values for key 'toilet' are not equal.
# Index: 305 , Values for key 'bottle' are not equal.
# Index: 306 , Values for key 'toilet' are not equal.
# Index: 307 , Values for key 'bottle' are not equal.
# Index: 308 , Values for key 'bottle' are not equal.
# Index: 308 , Values for key 'toilet' are not equal.
# Index: 309 , Values for key 'bottle' are not equal.
# Index: 310 , Values for key 'toilet' are not equal.
# Index: 311 , Values for key 'bottle' are not equal.
# Index: 311 , Values for key 'toilet' are not equal.
# Index: 312 , Values for key 'bottle' are not equal.
# Index: 312 , Values for key 'toilet' are not equal.
# Index: 313 , Values for key 'toilet' are not equal.
# Index: 314 , Values for key 'sink' are not equal.
# Index: 315 , Values for key 'toilet' are not equal.
# Index: 315 , Values for key 'sink' are not equal.
# Index: 316 , Values for key 'toilet' are not equal.
# Index: 317 , Values for key 'toilet' are not equal.
# Index: 318 , Values for key 'sink' are not equal.
# Index: 319 , Values for key 'toilet' are not equal.
# Index: 319 , Values for key 'sink' are not equal.
# Index: 320 , Values for key 'toilet' are not equal.
# Index: 321 , Values for key 'toilet' are not equal.
# Index: 322 , Values for key 'sink' are not equal.
# Index: 323 , Values for key 'sink' are not equal.
# Index: 324 , Values for key 'toilet' are not equal.
# Index: 325 , Values for key 'dog' are not equal.
# Index: 326 , Values for key 'toilet' are not equal.
# Index: 327 , Values for key 'dog' are not equal.
# Index: 327 , Values for key 'toilet' are not equal.
# Index: 328 , Values for key 'dog' are not equal.
# Index: 328 , Values for key 'toilet' are not equal.
# Index: 329 , Values for key 'dog' are not equal.
# Index: 330 , Values for key 'toilet' are not equal.
# Index: 331 , Values for key 'dog' are not equal.
# Index: 331 , Values for key 'toilet' are not equal.
# Index: 332 , Values for key 'dog' are not equal.
# Index: 332 , Values for key 'toilet' are not equal.
# Index: 333 , Values for key 'dog' are not equal.
# Index: 334 , Values for key 'toilet' are not equal.
# Index: 335 , Values for key 'dog' are not equal.
# Index: 335 , Values for key 'toilet' are not equal.
# Index: 336 , Values for key 'dog' are not equal.
# Index: 336 , Values for key 'toilet' are not equal.
# Index: 337 , Values for key 'dog' are not equal.
# Index: 339 , Values for key 'dog' are not equal.
# Index: 340 , Values for key 'dog' are not equal.
# Index: 341 , Values for key 'dog' are not equal.
# Index: 343 , Values for key 'dog' are not equal.
# Index: 344 , Values for key 'dog' are not equal.
# Index: 345 , Values for key 'dog' are not equal.
# Index: 347 , Values for key 'dog' are not equal.
# Index: 348 , Values for key 'dog' are not equal.
# Index: 349 , Values for key 'dog' are not equal.
# Index: 350 , Values for key 'car' are not equal.
# Index: 351 , Values for key 'dog' are not equal.
# Index: 351 , Values for key 'car' are not equal.
# Index: 352 , Values for key 'dog' are not equal.
# Index: 352 , Values for key 'car' are not equal.
# Index: 353 , Values for key 'dog' are not equal.
# Index: 354 , Values for key 'car' are not equal.
# Index: 355 , Values for key 'dog' are not equal.
# Index: 355 , Values for key 'car' are not equal.
# Index: 356 , Values for key 'dog' are not equal.
# Index: 356 , Values for key 'car' are not equal.
# Index: 357 , Values for key 'dog' are not equal.
# Index: 358 , Values for key 'car' are not equal.
# Index: 359 , Values for key 'dog' are not equal.
# Index: 359 , Values for key 'car' are not equal.
# Index: 360 , Values for key 'dog' are not equal.
# Index: 360 , Values for key 'car' are not equal.
# Index: 361 , Values for key 'car' are not equal.
# Index: 362 , Values for key 'truck' are not equal.
# Index: 363 , Values for key 'car' are not equal.
# Index: 363 , Values for key 'truck' are not equal.
# Index: 364 , Values for key 'car' are not equal.
# Index: 364 , Values for key 'truck' are not equal.
# Index: 365 , Values for key 'car' are not equal.
# Index: 366 , Values for key 'truck' are not equal.
# Index: 367 , Values for key 'car' are not equal.
# Index: 367 , Values for key 'truck' are not equal.
# Index: 368 , Values for key 'car' are not equal.
# Index: 368 , Values for key 'truck' are not equal.
# Index: 369 , Values for key 'car' are not equal.
# Index: 370 , Values for key 'truck' are not equal.
# Index: 371 , Values for key 'car' are not equal.
# Index: 371 , Values for key 'truck' are not equal.
# Index: 372 , Values for key 'car' are not equal.
# Index: 372 , Values for key 'truck' are not equal.
# Index: 373 , Values for key 'dog' are not equal.
# Index: 374 , Values for key 'backpack' are not equal.
# Index: 375 , Values for key 'dog' are not equal.
# Index: 375 , Values for key 'backpack' are not equal.
# Index: 376 , Values for key 'dog' are not equal.
# Index: 376 , Values for key 'backpack' are not equal.
# Index: 377 , Values for key 'dog' are not equal.
# Index: 378 , Values for key 'backpack' are not equal.
# Index: 379 , Values for key 'dog' are not equal.
# Index: 379 , Values for key 'backpack' are not equal.
# Index: 380 , Values for key 'dog' are not equal.
# Index: 380 , Values for key 'backpack' are not equal.
# Index: 381 , Values for key 'dog' are not equal.
# Index: 382 , Values for key 'backpack' are not equal.
# Index: 383 , Values for key 'dog' are not equal.
# Index: 383 , Values for key 'backpack' are not equal.
# Index: 384 , Values for key 'dog' are not equal.
# Index: 384 , Values for key 'backpack' are not equal.
# Index: 385 , Values for key 'backpack' are not equal.
# Index: 386 , Values for key 'truck' are not equal.
# Index: 387 , Values for key 'backpack' are not equal.
# Index: 387 , Values for key 'truck' are not equal.
# Index: 388 , Values for key 'backpack' are not equal.
# Index: 388 , Values for key 'truck' are not equal.
# Index: 389 , Values for key 'backpack' are not equal.
# Index: 390 , Values for key 'truck' are not equal.
# Index: 391 , Values for key 'backpack' are not equal.
# Index: 391 , Values for key 'truck' are not equal.
# Index: 392 , Values for key 'backpack' are not equal.
# Index: 392 , Values for key 'truck' are not equal.
# Index: 393 , Values for key 'backpack' are not equal.
# Index: 394 , Values for key 'truck' are not equal.
# Index: 395 , Values for key 'backpack' are not equal.
# Index: 395 , Values for key 'truck' are not equal.
# Index: 396 , Values for key 'backpack' are not equal.
# Index: 396 , Values for key 'truck' are not equal.
# Index: 397 , Values for key 'dog' are not equal.
# Index: 399 , Values for key 'dog' are not equal.
# Index: 400 , Values for key 'dog' are not equal.
# Index: 403 , Values for key 'dog' are not equal.
# Index: 404 , Values for key 'dog' are not equal.
# Index: 405 , Values for key 'dog' are not equal.
# Index: 407 , Values for key 'dog' are not equal.
# Index: 408 , Values for key 'dog' are not equal.
# Index: 409 , Values for key 'dog' are not equal.
# Index: 410 , Values for key 'dog' are not equal.
# Index: 412 , Values for key 'dog' are not equal.
# Index: 413 , Values for key 'dog' are not equal.
# Index: 414 , Values for key 'dog' are not equal.
# Index: 415 , Values for key 'bench' are not equal.
# Index: 416 , Values for key 'dog' are not equal.
# Index: 417 , Values for key 'dog' are not equal.
# Index: 418 , Values for key 'dog' are not equal.
# Index: 419 , Values for key 'bench' are not equal.
# Index: 420 , Values for key 'dog' are not equal.
# Index: 421 , Values for key 'dog' are not equal.
# Index: 421 , Values for key 'bench' are not equal.
# Index: 423 , Values for key 'dog' are not equal.
# Index: 425 , Values for key 'dog' are not equal.
# Index: 426 , Values for key 'dog' are not equal.
# Index: 427 , Values for key 'dog' are not equal.
# Index: 429 , Values for key 'dog' are not equal.
# Index: 430 , Values for key 'dog' are not equal.
# Index: 431 , Values for key 'dog' are not equal.
# Index: 433 , Values for key 'dog' are not equal.
# Index: 434 , Values for key 'dog' are not equal.
# Index: 436 , Values for key 'cup' are not equal.
# Index: 437 , Values for key 'cup' are not equal.
# Index: 438 , Values for key 'cup' are not equal.
# Index: 440 , Values for key 'cup' are not equal.
# Index: 441 , Values for key 'cup' are not equal.
# Index: 442 , Values for key 'cup' are not equal.
# Index: 444 , Values for key 'cup' are not equal.
# Index: 445 , Values for key 'cup' are not equal.
# Index: 446 , Values for key 'cup' are not equal.
# Index: 447 , Values for key 'plant' are not equal.
# Index: 448 , Values for key 'refrigerator' are not equal.
# Index: 449 , Values for key 'plant' are not equal.
# Index: 449 , Values for key 'refrigerator' are not equal.
# Index: 450 , Values for key 'plant' are not equal.
# Index: 450 , Values for key 'refrigerator' are not equal.
# Index: 451 , Values for key 'plant' are not equal.
# Index: 453 , Values for key 'plant' are not equal.
# Index: 453 , Values for key 'refrigerator' are not equal.
# Index: 454 , Values for key 'plant' are not equal.
# Index: 454 , Values for key 'refrigerator' are not equal.
# Index: 455 , Values for key 'plant' are not equal.
# Index: 457 , Values for key 'plant' are not equal.
# Index: 457 , Values for key 'refrigerator' are not equal.
# Index: 458 , Values for key 'plant' are not equal.
# Index: 460 , Values for key 'microwave' are not equal.
# Index: 461 , Values for key 'refrigerator' are not equal.
# Index: 461 , Values for key 'microwave' are not equal.
# Index: 462 , Values for key 'refrigerator' are not equal.
# Index: 462 , Values for key 'microwave' are not equal.
# Index: 463 , Values for key 'refrigerator' are not equal.
# Index: 464 , Values for key 'microwave' are not equal.
# Index: 465 , Values for key 'microwave' are not equal.
# Index: 466 , Values for key 'microwave' are not equal.
# Index: 467 , Values for key 'refrigerator' are not equal.
# Index: 468 , Values for key 'microwave' are not equal.
# Index: 469 , Values for key 'refrigerator' are not equal.
# Index: 470 , Values for key 'refrigerator' are not equal.
# Index: 471 , Values for key 'microwave' are not equal.
# Index: 472 , Values for key 'oven' are not equal.
# Index: 473 , Values for key 'microwave' are not equal.
# Index: 473 , Values for key 'oven' are not equal.
# Index: 474 , Values for key 'oven' are not equal.
# Index: 475 , Values for key 'microwave' are not equal.
# Index: 476 , Values for key 'oven' are not equal.
# Index: 477 , Values for key 'oven' are not equal.
# Index: 478 , Values for key 'oven' are not equal.
# Index: 479 , Values for key 'microwave' are not equal.
# Index: 480 , Values for key 'oven' are not equal.
# Index: 481 , Values for key 'oven' are not equal.
# Index: 482 , Values for key 'oven' are not equal.
# Index: 483 , Values for key 'oven' are not equal.
# Index: 484 , Values for key 'toaster' are not equal.
# Index: 485 , Values for key 'oven' are not equal.
# Index: 486 , Values for key 'oven' are not equal.
# Index: 487 , Values for key 'oven' are not equal.
# Index: 488 , Values for key 'toaster' are not equal.
# Index: 489 , Values for key 'oven' are not equal.
# Index: 490 , Values for key 'oven' are not equal.
# Index: 491 , Values for key 'oven' are not equal.
# Index: 493 , Values for key 'oven' are not equal.
# Index: 494 , Values for key 'oven' are not equal.
# Index: 494 , Values for key 'toaster' are not equal.
# Index: 495 , Values for key 'toaster' are not equal.
# Index: 497 , Values for key 'toaster' are not equal.
# Index: 498 , Values for key 'toaster' are not equal.
# Index: 499 , Values for key 'toaster' are not equal.
# Index: 502 , Values for key 'toaster' are not equal.
# Index: 503 , Values for key 'toaster' are not equal.
# Index: 505 , Values for key 'toaster' are not equal.
# Index: 506 , Values for key 'toaster' are not equal.
# Index: 519 , Values for key 'plant' are not equal.
# Index: 520 , Values for key 'microwave' are not equal.
# Index: 521 , Values for key 'plant' are not equal.
# Index: 521 , Values for key 'microwave' are not equal.
# Index: 522 , Values for key 'microwave' are not equal.
# Index: 523 , Values for key 'plant' are not equal.
# Index: 524 , Values for key 'microwave' are not equal.
# Index: 525 , Values for key 'plant' are not equal.
# Index: 525 , Values for key 'microwave' are not equal.
# Index: 526 , Values for key 'plant' are not equal.
# Index: 526 , Values for key 'microwave' are not equal.
# Index: 527 , Values for key 'plant' are not equal.
# Index: 528 , Values for key 'microwave' are not equal.
# Index: 529 , Values for key 'microwave' are not equal.
# Index: 530 , Values for key 'plant' are not equal.
# Index: 530 , Values for key 'microwave' are not equal.
# Index: 531 , Values for key 'microwave' are not equal.
# Index: 532 , Values for key 'oven' are not equal.
# Index: 533 , Values for key 'microwave' are not equal.
# Index: 533 , Values for key 'oven' are not equal.
# Index: 534 , Values for key 'microwave' are not equal.
# Index: 534 , Values for key 'oven' are not equal.
# Index: 535 , Values for key 'microwave' are not equal.
# Index: 536 , Values for key 'oven' are not equal.
# Index: 537 , Values for key 'microwave' are not equal.
# Index: 537 , Values for key 'oven' are not equal.
# Index: 538 , Values for key 'microwave' are not equal.
# Index: 538 , Values for key 'oven' are not equal.
# Index: 539 , Values for key 'microwave' are not equal.
# Index: 540 , Values for key 'oven' are not equal.
# Index: 541 , Values for key 'microwave' are not equal.
# Index: 541 , Values for key 'oven' are not equal.
# Index: 542 , Values for key 'microwave' are not equal.
# Index: 542 , Values for key 'oven' are not equal.
# Index: 543 , Values for key 'oven' are not equal.
# Index: 544 , Values for key 'vase' are not equal.
# Index: 545 , Values for key 'oven' are not equal.
# Index: 545 , Values for key 'vase' are not equal.
# Index: 546 , Values for key 'oven' are not equal.
# Index: 546 , Values for key 'vase' are not equal.
# Index: 547 , Values for key 'oven' are not equal.
# Index: 548 , Values for key 'vase' are not equal.
# Index: 549 , Values for key 'oven' are not equal.
# Index: 549 , Values for key 'vase' are not equal.
# Index: 550 , Values for key 'oven' are not equal.
# Index: 550 , Values for key 'vase' are not equal.
# Index: 551 , Values for key 'oven' are not equal.
# Index: 552 , Values for key 'vase' are not equal.
# Index: 553 , Values for key 'oven' are not equal.
# Index: 553 , Values for key 'vase' are not equal.
# Index: 554 , Values for key 'oven' are not equal.
# Index: 554 , Values for key 'vase' are not equal.
# Index: 555 , Values for key 'vase' are not equal.
# Index: 556 , Values for key 'sink' are not equal.
# Index: 557 , Values for key 'vase' are not equal.
# Index: 557 , Values for key 'sink' are not equal.
# Index: 558 , Values for key 'vase' are not equal.
# Index: 558 , Values for key 'sink' are not equal.
# Index: 559 , Values for key 'vase' are not equal.
# Index: 560 , Values for key 'sink' are not equal.
# Index: 561 , Values for key 'vase' are not equal.
# Index: 561 , Values for key 'sink' are not equal.
# Index: 562 , Values for key 'vase' are not equal.
# Index: 562 , Values for key 'sink' are not equal.
# Index: 563 , Values for key 'vase' are not equal.
# Index: 564 , Values for key 'sink' are not equal.
# Index: 565 , Values for key 'vase' are not equal.
# Index: 565 , Values for key 'sink' are not equal.
# Index: 566 , Values for key 'vase' are not equal.
# Index: 566 , Values for key 'sink' are not equal.
# Index: 567 , Values for key 'sink' are not equal.
# Index: 568 , Values for key 'refrigerator' are not equal.
# Index: 569 , Values for key 'sink' are not equal.
# Index: 569 , Values for key 'refrigerator' are not equal.
# Index: 570 , Values for key 'sink' are not equal.
# Index: 570 , Values for key 'refrigerator' are not equal.
# Index: 571 , Values for key 'sink' are not equal.
# Index: 572 , Values for key 'refrigerator' are not equal.
# Index: 573 , Values for key 'sink' are not equal.
# Index: 573 , Values for key 'refrigerator' are not equal.
# Index: 574 , Values for key 'sink' are not equal.
# Index: 574 , Values for key 'refrigerator' are not equal.
# Index: 575 , Values for key 'sink' are not equal.
# Index: 576 , Values for key 'refrigerator' are not equal.
# Index: 577 , Values for key 'sink' are not equal.
# Index: 577 , Values for key 'refrigerator' are not equal.
# Index: 578 , Values for key 'sink' are not equal.
# Index: 578 , Values for key 'refrigerator' are not equal.
# Index: 592 , Values for key 'spoon' are not equal.
# Index: 593 , Values for key 'spoon' are not equal.
# Index: 594 , Values for key 'spoon' are not equal.
# Index: 596 , Values for key 'spoon' are not equal.
# Index: 597 , Values for key 'spoon' are not equal.
# Index: 598 , Values for key 'spoon' are not equal.
# Index: 600 , Values for key 'spoon' are not equal.
# Index: 601 , Values for key 'spoon' are not equal.
# Index: 602 , Values for key 'spoon' are not equal.
# Index: 603 , Values for key 'spoon' are not equal.
# Index: 605 , Values for key 'spoon' are not equal.
# Index: 606 , Values for key 'spoon' are not equal.
# Index: 606 , Values for key 'refrigerator' are not equal.
# Index: 607 , Values for key 'spoon' are not equal.
# Index: 608 , Values for key 'refrigerator' are not equal.
# Index: 609 , Values for key 'spoon' are not equal.
# Index: 610 , Values for key 'spoon' are not equal.
# Index: 611 , Values for key 'spoon' are not equal.
# Index: 613 , Values for key 'spoon' are not equal.
# Index: 614 , Values for key 'spoon' are not equal.
# Index: 618 , Values for key 'refrigerator' are not equal.
# Index: 619 , Values for key 'refrigerator' are not equal.
# Index: 623 , Values for key 'refrigerator' are not equal.
# Index: 626 , Values for key 'refrigerator' are not equal.
# Index: 628 , Values for key 'apple' are not equal.
# Index: 629 , Values for key 'apple' are not equal.
# Index: 630 , Values for key 'apple' are not equal.
# Index: 632 , Values for key 'apple' are not equal.
# Index: 633 , Values for key 'apple' are not equal.
# Index: 634 , Values for key 'apple' are not equal.
# Index: 636 , Values for key 'apple' are not equal.
# Index: 637 , Values for key 'apple' are not equal.
# Index: 638 , Values for key 'apple' are not equal.
# Index: 639 , Values for key 'plant' are not equal.
# Index: 640 , Values for key 'dining' are not equal.
# Index: 641 , Values for key 'plant' are not equal.
# Index: 641 , Values for key 'dining' are not equal.
# Index: 642 , Values for key 'plant' are not equal.
# Index: 642 , Values for key 'dining' are not equal.
# Index: 643 , Values for key 'plant' are not equal.
# Index: 644 , Values for key 'dining' are not equal.
# Index: 645 , Values for key 'plant' are not equal.
# Index: 645 , Values for key 'dining' are not equal.
# Index: 646 , Values for key 'plant' are not equal.
# Index: 646 , Values for key 'dining' are not equal.
# Index: 647 , Values for key 'plant' are not equal.
# Index: 648 , Values for key 'dining' are not equal.
# Index: 649 , Values for key 'plant' are not equal.
# Index: 649 , Values for key 'dining' are not equal.
# Index: 650 , Values for key 'plant' are not equal.
# Index: 650 , Values for key 'dining' are not equal.
# Index: 651 , Values for key 'dining' are not equal.
# Index: 653 , Values for key 'dining' are not equal.
# Index: 653 , Values for key 'refrigerator' are not equal.
# Index: 654 , Values for key 'dining' are not equal.
# Index: 654 , Values for key 'refrigerator' are not equal.
# Index: 655 , Values for key 'dining' are not equal.
# Index: 656 , Values for key 'refrigerator' are not equal.
# Index: 657 , Values for key 'dining' are not equal.
# Index: 657 , Values for key 'refrigerator' are not equal.
# Index: 658 , Values for key 'dining' are not equal.
# Index: 658 , Values for key 'refrigerator' are not equal.
# Index: 659 , Values for key 'dining' are not equal.
# Index: 660 , Values for key 'refrigerator' are not equal.
# Index: 661 , Values for key 'dining' are not equal.
# Index: 661 , Values for key 'refrigerator' are not equal.
# Index: 662 , Values for key 'dining' are not equal.
# Index: 662 , Values for key 'refrigerator' are not equal.
# Index: 665 , Values for key 'refrigerator' are not equal.
# Index: 666 , Values for key 'refrigerator' are not equal.
# Index: 667 , Values for key 'refrigerator' are not equal.
# Index: 669 , Values for key 'refrigerator' are not equal.
# Index: 670 , Values for key 'refrigerator' are not equal.
# Index: 671 , Values for key 'refrigerator' are not equal.
# Index: 676 , Values for key 'microwave' are not equal.
# Index: 678 , Values for key 'microwave' are not equal.
# Index: 680 , Values for key 'microwave' are not equal.
# Index: 681 , Values for key 'microwave' are not equal.
# Index: 682 , Values for key 'microwave' are not equal.
# Index: 684 , Values for key 'microwave' are not equal.
# Index: 686 , Values for key 'microwave' are not equal.
# Index: 689 , Values for key 'microwave' are not equal.
# Index: 690 , Values for key 'microwave' are not equal.
# Index: 691 , Values for key 'microwave' are not equal.
# Index: 693 , Values for key 'microwave' are not equal.
# Index: 694 , Values for key 'microwave' are not equal.
# Index: 695 , Values for key 'microwave' are not equal.
# Index: 697 , Values for key 'microwave' are not equal.
# Index: 698 , Values for key 'microwave' are not equal.
# Index: 708 , Values for key 'vase' are not equal.
# Index: 711 , Values for key 'plant' are not equal.
# Index: 724 , Values for key 'sink' are not equal.
# Index: 725 , Values for key 'sink' are not equal.
# Index: 726 , Values for key 'sink' are not equal.
# Index: 728 , Values for key 'sink' are not equal.
# Index: 729 , Values for key 'sink' are not equal.
# Index: 730 , Values for key 'sink' are not equal.
# Index: 732 , Values for key 'sink' are not equal.
# Index: 734 , Values for key 'sink' are not equal.
# Index: 735 , Values for key 'sink' are not equal.
# Index: 736 , Values for key 'chair' are not equal.
# Index: 737 , Values for key 'sink' are not equal.
# Index: 737 , Values for key 'chair' are not equal.
# Index: 738 , Values for key 'sink' are not equal.
# Index: 738 , Values for key 'chair' are not equal.
# Index: 739 , Values for key 'sink' are not equal.
# Index: 740 , Values for key 'chair' are not equal.
# Index: 741 , Values for key 'chair' are not equal.
# Index: 742 , Values for key 'sink' are not equal.
# Index: 742 , Values for key 'chair' are not equal.
# Index: 743 , Values for key 'sink' are not equal.
# Index: 744 , Values for key 'chair' are not equal.
# Index: 745 , Values for key 'sink' are not equal.
# Index: 745 , Values for key 'chair' are not equal.
# Index: 746 , Values for key 'sink' are not equal.
# Index: 746 , Values for key 'chair' are not equal.
# Index: 747 , Values for key 'plant' are not equal.
# Index: 749 , Values for key 'plant' are not equal.
# Index: 751 , Values for key 'plant' are not equal.
# Index: 752 , Values for key 'refrigerator' are not equal.
# Index: 754 , Values for key 'plant' are not equal.
# Index: 754 , Values for key 'refrigerator' are not equal.
# Index: 755 , Values for key 'plant' are not equal.
# Index: 756 , Values for key 'refrigerator' are not equal.
# Index: 757 , Values for key 'plant' are not equal.
# Index: 758 , Values for key 'plant' are not equal.
# Index: 759 , Values for key 'refrigerator' are not equal.
# Index: 762 , Values for key 'refrigerator' are not equal.
# Index: 763 , Values for key 'refrigerator' are not equal.
# Index: 766 , Values for key 'refrigerator' are not equal.
# Index: 812 , Values for key 'surfboard' are not equal.
# Index: 814 , Values for key 'surfboard' are not equal.
# Index: 817 , Values for key 'surfboard' are not equal.
# Index: 818 , Values for key 'surfboard' are not equal.
# Index: 819 , Values for key 'plant' are not equal.
# Index: 821 , Values for key 'plant' are not equal.
# Index: 821 , Values for key 'apple' are not equal.
# Index: 822 , Values for key 'plant' are not equal.
# Index: 823 , Values for key 'plant' are not equal.
# Index: 825 , Values for key 'plant' are not equal.
# Index: 825 , Values for key 'apple' are not equal.
# Index: 826 , Values for key 'plant' are not equal.
# Index: 826 , Values for key 'apple' are not equal.
# Index: 827 , Values for key 'plant' are not equal.
# Index: 829 , Values for key 'plant' are not equal.
# Index: 829 , Values for key 'apple' are not equal.
# Index: 830 , Values for key 'plant' are not equal.
# Index: 831 , Values for key 'apple' are not equal.
# Index: 832 , Values for key 'microwave' are not equal.
# Index: 833 , Values for key 'apple' are not equal.
# Index: 833 , Values for key 'microwave' are not equal.
# Index: 834 , Values for key 'microwave' are not equal.
# Index: 836 , Values for key 'microwave' are not equal.
# Index: 837 , Values for key 'microwave' are not equal.
# Index: 838 , Values for key 'microwave' are not equal.
# Index: 840 , Values for key 'microwave' are not equal.
# Index: 841 , Values for key 'microwave' are not equal.
# Index: 842 , Values for key 'microwave' are not equal.
# Index: 843 , Values for key 'microwave' are not equal.
# Index: 844 , Values for key 'oven' are not equal.
# Index: 845 , Values for key 'microwave' are not equal.
# Index: 845 , Values for key 'oven' are not equal.
# Index: 846 , Values for key 'microwave' are not equal.
# Index: 846 , Values for key 'oven' are not equal.
# Index: 847 , Values for key 'microwave' are not equal.
# Index: 848 , Values for key 'oven' are not equal.
# Index: 849 , Values for key 'microwave' are not equal.
# Index: 849 , Values for key 'oven' are not equal.
# Index: 850 , Values for key 'microwave' are not equal.
# Index: 850 , Values for key 'oven' are not equal.
# Index: 851 , Values for key 'microwave' are not equal.
# Index: 852 , Values for key 'oven' are not equal.
# Index: 853 , Values for key 'microwave' are not equal.
# Index: 853 , Values for key 'oven' are not equal.
# Index: 854 , Values for key 'microwave' are not equal.
# Index: 854 , Values for key 'oven' are not equal.
# Index: 855 , Values for key 'oven' are not equal.
# Index: 856 , Values for key 'sink' are not equal.
# Index: 857 , Values for key 'oven' are not equal.
# Index: 857 , Values for key 'sink' are not equal.
# Index: 858 , Values for key 'oven' are not equal.
# Index: 859 , Values for key 'oven' are not equal.
# Index: 860 , Values for key 'sink' are not equal.
# Index: 861 , Values for key 'oven' are not equal.
# Index: 862 , Values for key 'oven' are not equal.
# Index: 862 , Values for key 'sink' are not equal.
# Index: 863 , Values for key 'oven' are not equal.
# Index: 864 , Values for key 'sink' are not equal.
# Index: 865 , Values for key 'oven' are not equal.
# Index: 865 , Values for key 'sink' are not equal.
# Index: 866 , Values for key 'oven' are not equal.
# Index: 867 , Values for key 'plant' are not equal.
# Index: 869 , Values for key 'plant' are not equal.
# Index: 870 , Values for key 'plant' are not equal.
# Index: 871 , Values for key 'plant' are not equal.
# Index: 873 , Values for key 'plant' are not equal.
# Index: 874 , Values for key 'plant' are not equal.
# Index: 875 , Values for key 'plant' are not equal.
# Index: 877 , Values for key 'plant' are not equal.
# Index: 878 , Values for key 'plant' are not equal.
# Index: 880 , Values for key 'refrigerator' are not equal.
# Index: 881 , Values for key 'refrigerator' are not equal.
# Index: 882 , Values for key 'refrigerator' are not equal.
# Index: 884 , Values for key 'refrigerator' are not equal.
# Index: 885 , Values for key 'refrigerator' are not equal.
# Index: 886 , Values for key 'refrigerator' are not equal.
# Index: 888 , Values for key 'refrigerator' are not equal.
# Index: 889 , Values for key 'refrigerator' are not equal.
# Index: 890 , Values for key 'refrigerator' are not equal.
# Index: 891 , Values for key 'refrigerator' are not equal.
# Index: 892 , Values for key 'banana' are not equal.
# Index: 893 , Values for key 'refrigerator' are not equal.
# Index: 893 , Values for key 'banana' are not equal.
# Index: 894 , Values for key 'refrigerator' are not equal.
# Index: 894 , Values for key 'banana' are not equal.
# Index: 895 , Values for key 'refrigerator' are not equal.
# Index: 896 , Values for key 'banana' are not equal.
# Index: 897 , Values for key 'refrigerator' are not equal.
# Index: 897 , Values for key 'banana' are not equal.
# Index: 898 , Values for key 'refrigerator' are not equal.
# Index: 898 , Values for key 'banana' are not equal.
# Index: 899 , Values for key 'refrigerator' are not equal.
# Index: 900 , Values for key 'banana' are not equal.
# Index: 901 , Values for key 'refrigerator' are not equal.
# Index: 901 , Values for key 'banana' are not equal.
# Index: 902 , Values for key 'refrigerator' are not equal.
# Index: 902 , Values for key 'banana' are not equal.
# Index: 903 , Values for key 'banana' are not equal.
# Index: 904 , Values for key 'oven' are not equal.
# Index: 905 , Values for key 'banana' are not equal.
# Index: 905 , Values for key 'oven' are not equal.
# Index: 906 , Values for key 'banana' are not equal.
# Index: 906 , Values for key 'oven' are not equal.
# Index: 907 , Values for key 'banana' are not equal.
# Index: 908 , Values for key 'oven' are not equal.
# Index: 909 , Values for key 'banana' are not equal.
# Index: 909 , Values for key 'oven' are not equal.
# Index: 910 , Values for key 'banana' are not equal.
# Index: 910 , Values for key 'oven' are not equal.
# Index: 911 , Values for key 'banana' are not equal.
# Index: 912 , Values for key 'oven' are not equal.
# Index: 913 , Values for key 'banana' are not equal.
# Index: 913 , Values for key 'oven' are not equal.
# Index: 914 , Values for key 'banana' are not equal.
# Index: 914 , Values for key 'oven' are not equal.
# Index: 915 , Values for key 'oven' are not equal.
# Index: 916 , Values for key 'sink' are not equal.
# Index: 917 , Values for key 'oven' are not equal.
# Index: 917 , Values for key 'sink' are not equal.
# Index: 918 , Values for key 'oven' are not equal.
# Index: 918 , Values for key 'sink' are not equal.
# Index: 919 , Values for key 'oven' are not equal.
# Index: 920 , Values for key 'sink' are not equal.
# Index: 921 , Values for key 'oven' are not equal.
# Index: 921 , Values for key 'sink' are not equal.
# Index: 922 , Values for key 'oven' are not equal.
# Index: 922 , Values for key 'sink' are not equal.
# Index: 923 , Values for key 'oven' are not equal.
# Index: 924 , Values for key 'sink' are not equal.
# Index: 925 , Values for key 'oven' are not equal.
# Index: 925 , Values for key 'sink' are not equal.
# Index: 926 , Values for key 'oven' are not equal.
# Index: 926 , Values for key 'sink' are not equal.
# Index: 927 , Values for key 'plant' are not equal.
# Index: 929 , Values for key 'plant' are not equal.
# Index: 930 , Values for key 'plant' are not equal.
# Index: 931 , Values for key 'plant' are not equal.
# Index: 933 , Values for key 'plant' are not equal.
# Index: 934 , Values for key 'plant' are not equal.
# Index: 935 , Values for key 'plant' are not equal.
# Index: 936 , Values for key 'dining' are not equal.
# Index: 937 , Values for key 'plant' are not equal.
# Index: 938 , Values for key 'plant' are not equal.
# Index: 939 , Values for key 'dining' are not equal.
# Index: 940 , Values for key 'oven' are not equal.
# Index: 941 , Values for key 'dining' are not equal.
# Index: 941 , Values for key 'oven' are not equal.
# Index: 942 , Values for key 'dining' are not equal.
# Index: 942 , Values for key 'oven' are not equal.
# Index: 944 , Values for key 'oven' are not equal.
# Index: 945 , Values for key 'oven' are not equal.
# Index: 946 , Values for key 'oven' are not equal.
# Index: 947 , Values for key 'dining' are not equal.
# Index: 948 , Values for key 'oven' are not equal.
# Index: 949 , Values for key 'dining' are not equal.
# ...
# Index: 4706 , Values for key 'bear' are not equal.
# Index: 4708 , Values for key 'bear' are not equal.
# Index: 4709 , Values for key 'bear' are not equal.
# Index: 4710 , Values for key 'bear' are not equal.
# Index: 4712 , Values for key 'bear' are not equal.
# Index: 4713 , Values for key 'bear' are not equal.
# Index: 4715 , Values for key 'refrigerator' are not equal.
# Index: 4716 , Values for key 'sink' are not equal.
# Index: 4717 , Values for key 'refrigerator' are not equal.
# Index: 4717 , Values for key 'sink' are not equal.
# Index: 4718 , Values for key 'refrigerator' are not equal.
# Index: 4718 , Values for key 'sink' are not equal.
# Index: 4719 , Values for key 'refrigerator' are not equal.
# Index: 4720 , Values for key 'sink' are not equal.
# Index: 4721 , Values for key 'refrigerator' are not equal.
# Index: 4721 , Values for key 'sink' are not equal.
# Index: 4722 , Values for key 'refrigerator' are not equal.
# Index: 4722 , Values for key 'sink' are not equal.
# Index: 4723 , Values for key 'refrigerator' are not equal.
# Index: 4724 , Values for key 'sink' are not equal.
# Index: 4725 , Values for key 'refrigerator' are not equal.
# Index: 4725 , Values for key 'sink' are not equal.
# Index: 4726 , Values for key 'refrigerator' are not equal.
# Index: 4726 , Values for key 'sink' are not equal.
# Index: 4727 , Values for key 'sink' are not equal.
# Index: 4728 , Values for key 'bottle' are not equal.
# Index: 4729 , Values for key 'sink' are not equal.
# Index: 4729 , Values for key 'bottle' are not equal.
# Index: 4730 , Values for key 'sink' are not equal.
# Index: 4730 , Values for key 'bottle' are not equal.
# Index: 4731 , Values for key 'sink' are not equal.
# Index: 4732 , Values for key 'bottle' are not equal.
# Index: 4733 , Values for key 'sink' are not equal.
# Index: 4733 , Values for key 'bottle' are not equal.
# Index: 4734 , Values for key 'sink' are not equal.
# Index: 4734 , Values for key 'bottle' are not equal.
# Index: 4735 , Values for key 'sink' are not equal.
# Index: 4736 , Values for key 'bottle' are not equal.
# Index: 4737 , Values for key 'sink' are not equal.
# Index: 4737 , Values for key 'bottle' are not equal.
# Index: 4738 , Values for key 'sink' are not equal.
# Index: 4739 , Values for key 'bottle' are not equal.
# Index: 4741 , Values for key 'bottle' are not equal.
# Index: 4742 , Values for key 'bottle' are not equal.
# Index: 4743 , Values for key 'bottle' are not equal.
# Index: 4745 , Values for key 'bottle' are not equal.
# Index: 4746 , Values for key 'bottle' are not equal.
# Index: 4747 , Values for key 'bottle' are not equal.
# Index: 4749 , Values for key 'bottle' are not equal.
# Index: 4750 , Values for key 'bottle' are not equal.
# Index: 4752 , Values for key 'microwave' are not equal.
# Index: 4753 , Values for key 'microwave' are not equal.
# Index: 4754 , Values for key 'microwave' are not equal.
# Index: 4756 , Values for key 'microwave' are not equal.
# Index: 4757 , Values for key 'microwave' are not equal.
# Index: 4758 , Values for key 'microwave' are not equal.
# Index: 4760 , Values for key 'microwave' are not equal.
# Index: 4761 , Values for key 'microwave' are not equal.
# Index: 4762 , Values for key 'microwave' are not equal.
# Index: 4763 , Values for key 'refrigerator' are not equal.
# Index: 4764 , Values for key 'oven' are not equal.
# Index: 4765 , Values for key 'oven' are not equal.
# Index: 4766 , Values for key 'oven' are not equal.
# Index: 4768 , Values for key 'oven' are not equal.
# Index: 4769 , Values for key 'oven' are not equal.
# Index: 4770 , Values for key 'refrigerator' are not equal.
# Index: 4770 , Values for key 'oven' are not equal.
# Index: 4771 , Values for key 'refrigerator' are not equal.
# Index: 4772 , Values for key 'oven' are not equal.
# Index: 4773 , Values for key 'refrigerator' are not equal.
# Index: 4773 , Values for key 'oven' are not equal.
# Index: 4774 , Values for key 'oven' are not equal.
# Index: 4775 , Values for key 'oven' are not equal.
# Index: 4776 , Values for key 'sink' are not equal.
# Index: 4777 , Values for key 'oven' are not equal.
# Index: 4777 , Values for key 'sink' are not equal.
# Index: 4778 , Values for key 'oven' are not equal.
# Index: 4778 , Values for key 'sink' are not equal.
# Index: 4779 , Values for key 'oven' are not equal.
# Index: 4780 , Values for key 'sink' are not equal.
# Index: 4781 , Values for key 'oven' are not equal.
# Index: 4781 , Values for key 'sink' are not equal.
# Index: 4782 , Values for key 'oven' are not equal.
# Index: 4782 , Values for key 'sink' are not equal.
# Index: 4783 , Values for key 'oven' are not equal.
# Index: 4784 , Values for key 'sink' are not equal.
# Index: 4785 , Values for key 'oven' are not equal.
# Index: 4785 , Values for key 'sink' are not equal.
# Index: 4786 , Values for key 'oven' are not equal.
# Index: 4786 , Values for key 'sink' are not equal.
# Index: 4787 , Values for key 'sink' are not equal.
# Index: 4788 , Values for key 'microwave' are not equal.
# Index: 4789 , Values for key 'sink' are not equal.
# Index: 4789 , Values for key 'microwave' are not equal.
# Index: 4790 , Values for key 'sink' are not equal.
# Index: 4790 , Values for key 'microwave' are not equal.
# Index: 4791 , Values for key 'sink' are not equal.
# Index: 4792 , Values for key 'microwave' are not equal.
# Index: 4793 , Values for key 'sink' are not equal.
# Index: 4793 , Values for key 'microwave' are not equal.
# Index: 4794 , Values for key 'sink' are not equal.
# Index: 4794 , Values for key 'microwave' are not equal.
# Index: 4795 , Values for key 'sink' are not equal.
# Index: 4796 , Values for key 'microwave' are not equal.
# Index: 4797 , Values for key 'sink' are not equal.
# Index: 4797 , Values for key 'microwave' are not equal.
# Index: 4798 , Values for key 'sink' are not equal.
# Index: 4798 , Values for key 'microwave' are not equal.
# Index: 4799 , Values for key 'refrigerator' are not equal.
# Index: 4800 , Values for key 'bottle' are not equal.
# Index: 4801 , Values for key 'refrigerator' are not equal.
# Index: 4801 , Values for key 'bottle' are not equal.
# Index: 4802 , Values for key 'refrigerator' are not equal.
# Index: 4802 , Values for key 'bottle' are not equal.
# Index: 4803 , Values for key 'refrigerator' are not equal.
# Index: 4804 , Values for key 'bottle' are not equal.
# Index: 4805 , Values for key 'refrigerator' are not equal.
# Index: 4805 , Values for key 'bottle' are not equal.
# Index: 4806 , Values for key 'refrigerator' are not equal.
# Index: 4806 , Values for key 'bottle' are not equal.
# Index: 4807 , Values for key 'refrigerator' are not equal.
# Index: 4808 , Values for key 'bottle' are not equal.
# Index: 4809 , Values for key 'refrigerator' are not equal.
# Index: 4809 , Values for key 'bottle' are not equal.
# Index: 4810 , Values for key 'refrigerator' are not equal.
# Index: 4810 , Values for key 'bottle' are not equal.
# Index: 4811 , Values for key 'bottle' are not equal.
# Index: 4812 , Values for key 'oven' are not equal.
# Index: 4813 , Values for key 'bottle' are not equal.
# Index: 4814 , Values for key 'bottle' are not equal.
# Index: 4814 , Values for key 'oven' are not equal.
# Index: 4815 , Values for key 'bottle' are not equal.
# Index: 4816 , Values for key 'oven' are not equal.
# Index: 4817 , Values for key 'bottle' are not equal.
# Index: 4818 , Values for key 'bottle' are not equal.
# Index: 4819 , Values for key 'bottle' are not equal.
# Index: 4820 , Values for key 'oven' are not equal.
# Index: 4821 , Values for key 'bottle' are not equal.
# Index: 4822 , Values for key 'bottle' are not equal.
# Index: 4823 , Values for key 'oven' are not equal.
# Index: 4824 , Values for key 'sink' are not equal.
# Index: 4825 , Values for key 'oven' are not equal.
# Index: 4825 , Values for key 'sink' are not equal.
# Index: 4826 , Values for key 'oven' are not equal.
# Index: 4826 , Values for key 'sink' are not equal.
# Index: 4827 , Values for key 'oven' are not equal.
# Index: 4828 , Values for key 'sink' are not equal.
# Index: 4829 , Values for key 'oven' are not equal.
# Index: 4829 , Values for key 'sink' are not equal.
# Index: 4830 , Values for key 'oven' are not equal.
# Index: 4830 , Values for key 'sink' are not equal.
# Index: 4831 , Values for key 'oven' are not equal.
# Index: 4832 , Values for key 'sink' are not equal.
# Index: 4833 , Values for key 'oven' are not equal.
# Index: 4833 , Values for key 'sink' are not equal.
# Index: 4834 , Values for key 'oven' are not equal.
# Index: 4834 , Values for key 'sink' are not equal.
# Index: 4835 , Values for key 'refrigerator' are not equal.
# Index: 4837 , Values for key 'refrigerator' are not equal.
# Index: 4837 , Values for key 'microwave' are not equal.
# Index: 4838 , Values for key 'refrigerator' are not equal.
# Index: 4838 , Values for key 'microwave' are not equal.
# Index: 4839 , Values for key 'refrigerator' are not equal.
# Index: 4840 , Values for key 'microwave' are not equal.
# Index: 4841 , Values for key 'refrigerator' are not equal.
# Index: 4842 , Values for key 'refrigerator' are not equal.
# Index: 4843 , Values for key 'refrigerator' are not equal.
# Index: 4844 , Values for key 'microwave' are not equal.
# Index: 4845 , Values for key 'refrigerator' are not equal.
# Index: 4845 , Values for key 'microwave' are not equal.
# Index: 4846 , Values for key 'refrigerator' are not equal.
# Index: 4847 , Values for key 'refrigerator' are not equal.
# Index: 4848 , Values for key 'clock' are not equal.
# Index: 4849 , Values for key 'refrigerator' are not equal.
# Index: 4849 , Values for key 'clock' are not equal.
# Index: 4850 , Values for key 'refrigerator' are not equal.
# Index: 4850 , Values for key 'clock' are not equal.
# Index: 4851 , Values for key 'refrigerator' are not equal.
# Index: 4852 , Values for key 'clock' are not equal.
# Index: 4853 , Values for key 'refrigerator' are not equal.
# Index: 4854 , Values for key 'refrigerator' are not equal.
# Index: 4854 , Values for key 'clock' are not equal.
# Index: 4855 , Values for key 'refrigerator' are not equal.
# Index: 4856 , Values for key 'clock' are not equal.
# Index: 4857 , Values for key 'refrigerator' are not equal.
# Index: 4857 , Values for key 'clock' are not equal.
# Index: 4858 , Values for key 'refrigerator' are not equal.
# Index: 4859 , Values for key 'clock' are not equal.
# Index: 4861 , Values for key 'clock' are not equal.
# Index: 4862 , Values for key 'clock' are not equal.
# Index: 4863 , Values for key 'clock' are not equal.
# Index: 4864 , Values for key 'microwave' are not equal.
# Index: 4865 , Values for key 'clock' are not equal.
# Index: 4866 , Values for key 'clock' are not equal.
# Index: 4867 , Values for key 'clock' are not equal.
# Index: 4868 , Values for key 'microwave' are not equal.
# Index: 4869 , Values for key 'clock' are not equal.
# Index: 4869 , Values for key 'microwave' are not equal.
# Index: 4870 , Values for key 'clock' are not equal.
# Index: 4870 , Values for key 'microwave' are not equal.
# Index: 4871 , Values for key 'microwave' are not equal.
# Index: 4872 , Values for key 'backpack' are not equal.
# Index: 4873 , Values for key 'microwave' are not equal.
# Index: 4873 , Values for key 'backpack' are not equal.
# Index: 4874 , Values for key 'backpack' are not equal.
# Index: 4876 , Values for key 'backpack' are not equal.
# Index: 4878 , Values for key 'microwave' are not equal.
# Index: 4878 , Values for key 'backpack' are not equal.
# Index: 4879 , Values for key 'microwave' are not equal.
# Index: 4880 , Values for key 'backpack' are not equal.
# Index: 4881 , Values for key 'backpack' are not equal.
# Index: 4882 , Values for key 'microwave' are not equal.
# Index: 4882 , Values for key 'backpack' are not equal.
# Index: 4883 , Values for key 'backpack' are not equal.
# Index: 4884 , Values for key 'bag' are not equal.
# Index: 4885 , Values for key 'backpack' are not equal.
# Index: 4885 , Values for key 'bag' are not equal.
# Index: 4886 , Values for key 'backpack' are not equal.
# Index: 4886 , Values for key 'bag' are not equal.
# Index: 4887 , Values for key 'backpack' are not equal.
# Index: 4888 , Values for key 'bag' are not equal.
# Index: 4889 , Values for key 'backpack' are not equal.
# Index: 4889 , Values for key 'bag' are not equal.
# Index: 4890 , Values for key 'backpack' are not equal.
# Index: 4890 , Values for key 'bag' are not equal.
# Index: 4891 , Values for key 'backpack' are not equal.
# Index: 4892 , Values for key 'bag' are not equal.
# Index: 4893 , Values for key 'backpack' are not equal.
# Index: 4893 , Values for key 'bag' are not equal.
# Index: 4894 , Values for key 'backpack' are not equal.
# Index: 4894 , Values for key 'bag' are not equal.
# Index: 4895 , Values for key 'bag' are not equal.
# Index: 4897 , Values for key 'bag' are not equal.
# Index: 4898 , Values for key 'bag' are not equal.
# Index: 4899 , Values for key 'bag' are not equal.
# Index: 4901 , Values for key 'bag' are not equal.
# Index: 4902 , Values for key 'bag' are not equal.
# Index: 4903 , Values for key 'bag' are not equal.
# Index: 4905 , Values for key 'bag' are not equal.
# Index: 4906 , Values for key 'bag' are not equal.
# Index: 4908 , Values for key 'banana' are not equal.
# Index: 4910 , Values for key 'banana' are not equal.
# Index: 4912 , Values for key 'banana' are not equal.
# Index: 4919 , Values for key 'refrigerator' are not equal.
# Index: 4920 , Values for key 'oven' are not equal.
# Index: 4921 , Values for key 'refrigerator' are not equal.
# Index: 4921 , Values for key 'oven' are not equal.
# Index: 4922 , Values for key 'refrigerator' are not equal.
# Index: 4922 , Values for key 'oven' are not equal.
# Index: 4923 , Values for key 'refrigerator' are not equal.
# Index: 4924 , Values for key 'oven' are not equal.
# Index: 4925 , Values for key 'refrigerator' are not equal.
# Index: 4925 , Values for key 'oven' are not equal.
# Index: 4926 , Values for key 'refrigerator' are not equal.
# Index: 4926 , Values for key 'oven' are not equal.
# Index: 4927 , Values for key 'refrigerator' are not equal.
# Index: 4928 , Values for key 'oven' are not equal.
# Index: 4929 , Values for key 'refrigerator' are not equal.
# Index: 4929 , Values for key 'oven' are not equal.
# Index: 4930 , Values for key 'refrigerator' are not equal.
# Index: 4930 , Values for key 'oven' are not equal.
# Index: 4931 , Values for key 'oven' are not equal.
# Index: 4933 , Values for key 'oven' are not equal.
# Index: 4934 , Values for key 'oven' are not equal.
# Index: 4935 , Values for key 'oven' are not equal.
# Index: 4937 , Values for key 'oven' are not equal.
# Index: 4938 , Values for key 'oven' are not equal.
# Index: 4939 , Values for key 'oven' are not equal.
# Index: 4941 , Values for key 'oven' are not equal.
# Index: 4942 , Values for key 'oven' are not equal.
# Index: 4944 , Values for key 'bag' are not equal.
# Index: 4949 , Values for key 'bag' are not equal.
# Index: 4950 , Values for key 'bag' are not equal.
# Index: 4953 , Values for key 'bag' are not equal.
# Index: 4957 , Values for key 'bag' are not equal.
# Index: 4961 , Values for key 'bottle' are not equal.
# Index: 4965 , Values for key 'bag' are not equal.
# Index: 4968 , Values for key 'cup' are not equal.
# Index: 4969 , Values for key 'cup' are not equal.
# Index: 4970 , Values for key 'cup' are not equal.
# Index: 4972 , Values for key 'cup' are not equal.
# Index: 4973 , Values for key 'cup' are not equal.
# Index: 4974 , Values for key 'cup' are not equal.
# Index: 4976 , Values for key 'cup' are not equal.
# Index: 4977 , Values for key 'cup' are not equal.
# Index: 4978 , Values for key 'cup' are not equal.
# Index: 4979 , Values for key 'refrigerator' are not equal.
# Index: 4982 , Values for key 'refrigerator' are not equal.
# Index: 4986 , Values for key 'refrigerator' are not equal.
# Index: 4987 , Values for key 'refrigerator' are not equal.
# Index: 4989 , Values for key 'refrigerator' are not equal.
# Index: 4990 , Values for key 'refrigerator' are not equal.
# Index: 4992 , Values for key 'sink' are not equal.
# Index: 4993 , Values for key 'sink' are not equal.
# Index: 4994 , Values for key 'sink' are not equal.
# Index: 4996 , Values for key 'sink' are not equal.
# Index: 4997 , Values for key 'sink' are not equal.
# Index: 4998 , Values for key 'sink' are not equal.
# Positve Score 2707 , totalSentences:- 7575, Accuracy = 35.73597359735974

# %% [markdown]
# The above printed index are the row id (inference.csv (5000 rows)) where the positions of categories doesn't match

# %%
print(f'Positve Score {pos_score} , totalSentences:- {total_sentences}, Accuracy = {pos_score*100/total_sentences}')
# Out:
# Positve Score 2707 , totalSentences:- 7575, Accuracy = 35.73597359735974

# %%
precision = precision_score(original_values_array, generated_values_array, average='weighted',zero_division=1)
recall = recall_score(original_values_array, generated_values_array, average='weighted',zero_division=1)
f1 = f1_score(original_values_array, generated_values_array, average='weighted',zero_division=1)

print(f'Precision: {precision:.2f}')
print(f'Recall: {recall:.2f}')
print(f'F1 Score: {f1:.2f}')
# Out:
# Precision: nan
# Recall: nan
# F1 Score: nan

# %% [markdown]
# Evaluating the output of Classification Model

# %%
use_saved_results = True
if use_saved_results:
    df1 = pd.read_csv('saved_files_from_our_experiments/classification_results.csv')

else:
    df1 = pd.read_csv('classification_results.csv')

df1
# Out:
#       row_id  image_id  positionName categoryName predictedPosition
# 0          0    289343   middleRight          dog       middleRight
# 1          1     61471  bottomCenter          dog      bottomCenter
# 2          2    472375  middleCenter          dog      middleCenter
# 3          3    520301  middleCenter          dog      middleCenter
# 4          4    579321  middleCenter          dog      middleCenter
# ...      ...       ...           ...          ...               ...
# 4995    4995    424521    middleLeft   skateboard        middleLeft
# 4996    4996    428111    middleLeft   skateboard        bottomLeft
# 4997    4997     72281  bottomCenter   skateboard      bottomCenter
# 4998    4998     84492   middleRight   skateboard       middleRight
# 4999    4999    361506  middleCenter   skateboard         topCenter
#
# [5000 rows x 5 columns]

# %%
predictionScore = 0
totalSize = df1.shape[0]

actual_positions = df1['positionName']
generated_positions = df1['predictedPosition']

for _, row in df1.iterrows():
    actual_position = row['positionName']
    generated_position = row['predictedPosition']

    if actual_position == generated_position:
        predictionScore += 1

accuracy = (predictionScore * 100) / totalSize

print(f'Prediction Score: {predictionScore}, Total Size: {totalSize}, Accuracy: {accuracy}')
# Out:
# Prediction Score: 3254, Total Size: 5000, Accuracy: 65.08

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

precision = precision_score(actual_positions, generated_positions, average='weighted')
recall = recall_score(actual_positions, generated_positions, average='weighted')
f1 = f1_score(actual_positions, generated_positions, average='weighted')

print(f'Precision: {precision:.2f}')
print(f'Recall: {recall:.2f}')
print(f'F1 Score: {f1:.2f}')
# Out:
# Precision: 0.65
# Recall: 0.65
# F1 Score: 0.65
